# %% [markdown]
# # 3D figures

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
# This line configures matplotlib to show figures embedded in the notebook, 
# instead of poping up a new window. More about that later. 
# %pylab inline

from pylab import *
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
alpha = 0.7
phi_ext = 2 * pi * 0.5

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * cos(phi_p)*cos(phi_m) - alpha * cos(phi_ext - 2*phi_p)

phi_m = linspace(0, 2*pi, 100)
phi_p = linspace(0, 2*pi, 100)
X,Y = meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T

# %%
X.shape
# Out:
# (100, 100)

# %% [markdown]
# ## plot_surface

# %%
fig = plt.figure(figsize=(14,6))

# `ax` is a 3D-aware axis instance, because of the projection='3d' keyword argument to add_subplot
ax = fig.add_subplot(1, 2, 1, projection='3d')


'''
X Y Z 2D arrays  Z是二维的
rstride Array row stride(step size) cstride column stride 
cmap color map 

'''
p = ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# surface_plot with color grading and color bar
ax = fig.add_subplot(1, 2, 2, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm, linewidth=0, antialiased=False)

cb = fig.colorbar(p, shrink=0.5)

# %% [markdown]
# ## Plot 都是一维的

# %%
mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure(figsize=(6,6))
ax = fig.gca(projection='3d')
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)
# print(x)
# zdir 哪个方向作为z轴('x', 'y', or 'z')
ax.plot(x, y, z, zdir='z',label='parametric curve')
ax.legend()

plt.show()
print(x.shape)
print(y.shape) 
print(z.shape)
# Out:
# (100,)
# (100,)
# (100,)

# %% [markdown]
# ## scatter

# %%
def randrange(n, vmin, vmax):
    '''
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    '''
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')

n = 30
c, m, zlow, zhigh =('r', 'o', -50, -25)
xs = randrange(n, -2, 3)
ys = randrange(n, 0, 100)
zs = randrange(n, zlow, zhigh)
# xs yx zs 都是一维的
ax.scatter(xs, ys, zs, c=c, marker=m)

# 给坐标刻度，并命名
plt.xticks([-2, -1, 1.22, 3],['bad','normal', 'good', 'really good'])




plt.show()
